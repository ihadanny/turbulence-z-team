# %% [markdown]
# # Used for predicting ALSFRS_slope
# see https://www.synapse.org/#!Synapse:syn2873386/wiki/ .
# We assumed data is vectorized + clustered + 6 features were selected

# %%
from IPython.display import display

import pandas as pd
import numpy as np
import pickle
from sklearn import linear_model
from vectorizing_funcs import *
from modeling_funcs import *

# %% [markdown]
# ## Revectorize the selected data
# We now reload the metadata and the 6 attributes selected per cluster

# %%
# load all metadata
all_feature_metadata = pickle.load( open('../all_feature_metadata.pickle', 'rb') )
train_data_means = pickle.load( open('../all_data_means.pickle', 'rb') )
train_data_std = pickle.load( open('../all_data_std.pickle', 'rb') )
best_features_per_cluster = pickle.load( open('../best_features_per_cluster.pickle', 'rb') )

# reload the data imputed only for the 6 selected attributes per cluster
df = pd.read_csv('../all_data_selected.csv', sep='|', index_col=False, dtype="unicode")
vectorized, _ = vectorize(df, all_feature_metadata)
normalized, _ = normalize(vectorized, all_feature_metadata, train_data_means, train_data_std)
print normalized.shape
normalized.head()
# Out:
# (2424, 157)
#            family_ALS_hist_last  Hematocrit_mean  Hematocrit_pct_diff  \
# SubjectID
# 4752                          0                0                    0
# 7399                          0                0                    0
# 7750                          0                0                    0
# 8471                          0                0                    0
# 10244                         0                0                    0
#
#            Hematocrit_last  Hematocrit_mean_slope  weight_mean  \
# SubjectID
# 4752                     0                      0            0
# 7399                     0                      0            0
# 7750                     0                      0            0
# 8471                     0                      0            0
# 10244                    0                      0            0
#
#            weight_pct_diff  weight_last  weight_mean_slope  Sodium_mean  \
# SubjectID
# 4752                     0            0                  0            0
# 7399                     0            0                  0            0
# 7750                     0            0                  0            0
# 8471                     0            0                  0            0
# 10244                    0            0                  0            0
#
#                    ...           Absolute Basophil Count_last  \
# SubjectID          ...
# 4752               ...                                      0
# 7399               ...                                      0
# 7750               ...                                      0
# 8471               ...                                      0
# 10244              ...                                      0
#
#            Absolute Basophil Count_mean_slope  Protein_mean  Protein_pct_diff  \
# SubjectID
# 4752                                        0             0                 0
# 7399                                        0             0                 0
# 7750                                        0             0                 0
# 8471                                        0             0                 0
# 10244                                       0             0                 0
#
#            Protein_last  Protein_mean_slope  ALT(SGPT)_mean  \
# SubjectID
# 4752                  0                   0       -0.233554
# 7399                  0                   0       -0.554568
# 7750                  0                   0       -0.217818
# 8471                  0                   0       -0.438122
# 10244                 0                   0       -0.705633
#
#            ALT(SGPT)_pct_diff  ALT(SGPT)_last  ALT(SGPT)_mean_slope
# SubjectID
# 4752                 0.477111       -0.085517              0.184220
# 7399                -0.138073       -0.522152              0.168641
# 7750                -0.305173       -0.194676             -0.061059
# 8471                 0.296454       -0.121904              0.020523
# 10244                0.000000       -0.558538              0.000000
#
# [5 rows x 157 columns]

# %%
d = normalized.describe().T
d[d['std'] > 0.0].sort("std", ascending=False)
# Out:
#                                       count      mean       std        min  \
# ALSFRS_Total_pct_diff                  2424 -0.047159  0.790137  -6.547038
# ALSFRS_Total_mean_slope                2424 -0.033535  0.784779  -5.281644
# Creatinine_mean_slope                  2424  0.002000  0.670322 -17.645697
# Red Blood Cells (RBC)_last             2424  0.008402  0.667919  -0.031676
# Creatinine_mean                        2424 -0.006198  0.666185  -2.921525
# Creatinine_last                        2424 -0.005487  0.661580  -2.740160
# ALSFRS_Total_last                      2424 -0.059782  0.653128  -3.827927
# weight_mean                            2424  0.016009  0.646463  -2.237218
# weight_last                            2424  0.018261  0.644103  -2.215785
# onset_delta_last                       2424 -0.266832  0.642132  -5.868302
# ALSFRS_Total_mean                      2424 -0.044914  0.632082  -3.728697
# weight_mean_slope                      2424  0.029460  0.629081  -5.689943
# Sodium_pct_diff                        2424 -0.013363  0.602038 -24.268913
# pulse_last                             2424  0.033643  0.596993  -2.575990
# mouth_mean                             2424  0.038500  0.592979  -3.834249
# pulse_mean                             2424  0.034224  0.592243  -2.951803
# mouth_last                             2424  0.045209  0.578751  -4.285426
# Albumin_mean                           2424  0.017316  0.576268  -3.797916
# CK_mean_slope                          2424  0.003487  0.569167  -3.946456
# Albumin_last                           2424  0.018072  0.561666  -3.391170
# weight_pct_diff                        2424  0.025573  0.557701  -3.581341
# Calcium_mean                           2424  0.009659  0.556915  -3.379656
# ALT(SGPT)_mean                         2424 -0.010233  0.550898  -1.303600
# pulse_mean_slope                       2424  0.006284  0.543371  -5.626237
# Albumin_mean_slope                     2424 -0.005053  0.539669 -11.488805
# Bilirubin (Total)_pct_diff             2424  0.005452  0.523781  -2.255030
# Red Blood Cells (RBC)_mean             2424  0.002457  0.517447  -0.173784
# Bilirubin (Total)_last                 2424  0.006900  0.513640  -1.633498
# CK_mean                                2424 -0.037548  0.511039  -1.008779
# Unknown                                2424  0.008453  0.509531  -0.139054
# ...                                     ...       ...       ...        ...
# mouth_pct_diff                         2424  0.020539  0.404057  -4.726503
# Platelets_last                         2424  0.005819  0.397295  -2.389813
# Blood Urea Nitrogen (BUN)_pct_diff     2424 -0.001640  0.389531  -2.233343
# Platelets_mean                         2424  0.002605  0.387746  -2.522583
# Alkaline Phosphatase_pct_diff          2424 -0.008184  0.386401  -6.719028
# Asian                                  2424 -0.005348  0.378588  -0.093464
# Platelets_mean_slope                   2424  0.002974  0.370499  -8.774977
# Alkaline Phosphatase_mean              2424 -0.014804  0.367740  -2.257181
# respiratory_mean_slope                 2424  0.006474  0.366870  -4.822367
# Platelets_pct_diff                     2424  0.001429  0.361525  -5.694061
# Alkaline Phosphatase_last              2424 -0.016745  0.359015  -2.240458
# Alkaline Phosphatase_mean_slope        2424 -0.003370  0.350395 -12.637278
# Blood Urea Nitrogen (BUN)_mean_slope   2424 -0.003858  0.349671 -11.316294
# Calcium_mean_slope                     2424 -0.004512  0.342124 -13.716283
# Other                                  2424 -0.005430  0.333786  -0.061034
# respiratory_pct_diff                   2424 -0.000251  0.332453  -5.920352
# Calcium_pct_diff                       2424 -0.000736  0.329272  -2.927158
# Hispanic                               2424 -0.006440  0.316817  -0.064349
# Hematocrit_last                        2424  0.032468  0.305591  -3.192893
# Hematocrit_mean                        2424  0.032595  0.304200  -3.210383
# ALT(SGPT)_mean_slope                   2424  0.008401  0.296554  -3.526735
# Absolute Basophil Count_mean           2424 -0.031594  0.271666  -0.357254
# Absolute Basophil Count_last           2424 -0.031672  0.271567  -0.356671
# Potassium_mean                         2424 -0.002060  0.269505  -2.013075
# Absolute Basophil Count_pct_diff       2424 -0.014238  0.251329  -1.762579
# Bilirubin (Total)_mean_slope           2424  0.008697  0.227085  -2.902189
# Absolute Basophil Count_mean_slope     2424 -0.000934  0.203607  -3.761717
# Potassium_mean_slope                   2424  0.001528  0.117615  -1.491104
# Creatinine_pct_diff                    2424 -0.007746  0.010567  -0.034987
# Red Blood Cells (RBC)_pct_diff         2424 -0.003549  0.008858  -0.075029
#
#                                            25%  50%       75%        max
# ALSFRS_Total_pct_diff                 0.000000    0  0.000000  23.332401
# ALSFRS_Total_mean_slope               0.000000    0  0.000000  23.211877
# Creatinine_mean_slope                 0.000000    0  0.009950   4.796415
# Red Blood Cells (RBC)_last            0.000000    0  0.000000  32.874195
# Creatinine_mean                       0.000000    0  0.000000   8.175021
# Creatinine_last                       0.000000    0  0.000000  10.471321
# ALSFRS_Total_last                     0.000000    0  0.000000   1.746032
# weight_mean                           0.000000    0  0.000000   4.291975
# weight_last                           0.000000    0  0.000000   4.534911
# onset_delta_last                      0.000000    0  0.000000   0.238561
# ALSFRS_Total_mean                     0.000000    0  0.000000   1.771874
# weight_mean_slope                     0.000000    0  0.000000   7.515461
# Sodium_pct_diff                       0.000000    0  0.000000   3.677525
# pulse_last                            0.000000    0  0.000000   3.825252
# mouth_mean                            0.000000    0  0.198255   0.774327
# pulse_mean                            0.000000    0  0.000000   4.634580
# mouth_last                            0.000000    0  0.339593   0.760049
# Albumin_mean                          0.000000    0  0.000000   2.467427
# CK_mean_slope                         0.000000    0  0.000000  24.852481
# Albumin_last                          0.000000    0  0.000000   2.928880
# weight_pct_diff                       0.000000    0  0.000000   6.101320
# Calcium_mean                          0.000000    0  0.000000  20.416469
# ALT(SGPT)_mean                        0.000000    0  0.000000   9.200156
# pulse_mean_slope                      0.000000    0  0.000000   6.134001
# Albumin_mean_slope                    0.000000    0  0.000000   6.640454
# Bilirubin (Total)_pct_diff            0.000000    0  0.000000  16.324421
# Red Blood Cells (RBC)_mean            0.000000    0  0.000000  20.309042
# Bilirubin (Total)_last                0.000000    0  0.000000  11.008027
# CK_mean                               0.000000    0  0.000000   6.300247
# Unknown                               0.000000    0  0.000000   7.188486
# ...                                        ...  ...       ...        ...
# mouth_pct_diff                        0.000000    0  0.091954   6.083325
# Platelets_last                        0.000000    0  0.000000   5.425155
# Blood Urea Nitrogen (BUN)_pct_diff    0.000000    0  0.000000   6.454519
# Platelets_mean                        0.000000    0  0.000000   5.616837
# Alkaline Phosphatase_pct_diff         0.000000    0  0.000000   3.414744
# Asian                                 0.000000    0  0.000000  10.694922
# Platelets_mean_slope                  0.000000    0  0.000000   4.089531
# Alkaline Phosphatase_mean             0.000000    0  0.000000   3.372601
# respiratory_mean_slope                0.000000    0  0.000000   6.701411
# Platelets_pct_diff                    0.000000    0  0.000000   5.356582
# Alkaline Phosphatase_last             0.000000    0  0.000000   3.588903
# Alkaline Phosphatase_mean_slope       0.000000    0  0.000000   1.160440
# Blood Urea Nitrogen (BUN)_mean_slope  0.000000    0  0.000000   1.833133
# Calcium_mean_slope                    0.000000    0  0.000000   3.547938
# Other                                 0.000000    0  0.000000  16.377504
# respiratory_pct_diff                  0.000000    0  0.000000   7.707631
# Calcium_pct_diff                      0.000000    0  0.000000  10.187511
# Hispanic                              0.000000    0  0.000000  15.533847
# Hematocrit_last                       0.000000    0  0.000000   1.156602
# Hematocrit_mean                       0.000000    0  0.000000   1.205410
# ALT(SGPT)_mean_slope                  0.000000    0  0.000000   3.466323
# Absolute Basophil Count_mean          0.000000    0  0.000000   3.536746
# Absolute Basophil Count_last          0.000000    0  0.000000   3.530667
# Potassium_mean                        0.000000    0  0.000000   2.109744
# Absolute Basophil Count_pct_diff      0.000000    0  0.000000   4.884585
# Bilirubin (Total)_mean_slope          0.000000    0  0.000000   7.580691
# Absolute Basophil Count_mean_slope    0.000000    0  0.000000   6.963719
# Potassium_mean_slope                  0.000000    0  0.000000   3.273048
# Creatinine_pct_diff                  -0.021612    0  0.000000   0.000000
# Red Blood Cells (RBC)_pct_diff        0.000000    0  0.000000   0.000000
#
# [87 rows x 8 columns]

# %%
slope = pd.read_csv('../all_slope.csv', sep = '|', index_col="SubjectID")
clusters = pd.read_csv('../all_forest_clusters.csv', sep = '|', index_col="SubjectID")

clusters.index = clusters.index.astype(str)
slope.index = slope.index.astype(str)
normalized.index = normalized.index.astype(str)

X = normalized.join(clusters)
Y = slope.join(clusters)

print Y.shape, X.shape, clusters.shape
print clusters.groupby('cluster').size()
display(Y.head(3))
# Out:
# (2424, 2) (2424, 158) (2424, 1)
# cluster
# 0    485
# 1    485
# 2    484
# 3    485
# 4    485
# dtype: int64
#            ALSFRS_slope  cluster
# SubjectID
# 533           -0.965608        3
# 649           -0.921717        1
# 1234          -0.914787        4

# %% [markdown]
# ## Train a prediction model per cluster

# %%
model_per_cluster = get_model_per_cluster(X, Y)
# Out:
# cluster: 0 size: (485L,)
# 	 RMS error (0 is perfect): 0.68
# 	 explained variance score (1 is perfect): 0.12
# 3 sample predictions:  [-1.09292645 -1.20807845 -1.17834671]
# cluster: 1 size: (485L,)
# 	 RMS error (0 is perfect): 0.59
# 	 explained variance score (1 is perfect): 0.10
# 3 sample predictions:  [-0.87048105 -0.83821565 -1.12251943]
# cluster: 2 size: (484L,)
# 	 RMS error (0 is perfect): 0.50
# 	 explained variance score (1 is perfect): 0.08
# 3 sample predictions:  [-0.57570292 -0.8561992  -0.67032911]
# cluster: 3 size: (485L,)
# 	 RMS error (0 is perfect): 0.43
# 	 explained variance score (1 is perfect): 0.16
# 3 sample predictions:  [-0.97023595 -0.34908337 -0.70087308]
# cluster: 4 size: (485L,)
# 	 RMS error (0 is perfect): 0.36
# 	 explained variance score (1 is perfect): 0.13
# 3 sample predictions:  [-0.37882441 -0.2853792  -0.40252582]

# %%
with open("../model_per_cluster.pickle", "wb") as output_file:
    pickle.dump(model_per_cluster, output_file)

# %% [markdown]
# ## Apply the model on both `train` and `test`

# %%
for t in ['all', 'test']:
    print t
    df = pd.read_csv('../' + t + '_data_selected.csv', sep='|', index_col=False, dtype="unicode")
    vectorized, _ = vectorize(df, all_feature_metadata)
    normalized, _ = normalize(vectorized, all_feature_metadata, train_data_means, train_data_std)
    clusters = pd.read_csv('../' + t + '_forest_clusters.csv', sep = '|', index_col=0)

    clusters.index = clusters.index.astype(str)
    normalized.index = normalized.index.astype(str)

    X = normalized.join(clusters)
    print X.groupby('cluster').size()
    pred = X.apply(apply_model, args=[model_per_cluster], axis = 1)
    pred.to_csv('../' + t + '_prediction.csv',sep='|')

pred.head()
# Out:
# all
# cluster
# 0    485
# 1    485
# 2    484
# 3    485
# 4    485
# dtype: int64
# test
# cluster
# 0    109
# 1    128
# 2    116
# 3    119
# 4    122
# dtype: int64
#            cluster  prediction
# SubjectID
# 750059           0   -1.072264
# 762989           0   -1.330513
# 764548           0   -1.440569
# 766563           0   -1.270172
# 770063           0   -1.381811
