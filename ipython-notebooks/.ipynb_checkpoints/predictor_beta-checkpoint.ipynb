# %% [markdown]
# # Used for predicting ALSFRS_slope
# see https://www.synapse.org/#!Synapse:syn2873386/wiki/ .
# We assumed data is vectorized + clustered + 6 features were selected

# %%
from IPython.display import display

import pandas as pd
import numpy as np
import pickle
from sklearn import linear_model
from vectorizing_funcs import *
from modeling_funcs import *

# %% [markdown]
# ## Revectorize the selected data
# We now reload the metadata and the 6 attributes selected per cluster

# %%
all_feature_metadata = pickle.load( open('../all_feature_metadata.pickle', 'rb') )
train_data_means = pickle.load( open('../all_data_means.pickle', 'rb') )
train_data_std = pickle.load( open('../all_data_std.pickle', 'rb') )
best_features_per_cluster = pickle.load( open('../best_features_per_cluster.pickle', 'rb') )


df = pd.read_csv('../all_data_selected.csv', sep='|', index_col=False, dtype="unicode")
vectorized, _ = vectorize(df, all_feature_metadata)
normalized, _ = normalize(vectorized, all_feature_metadata, train_data_means, train_data_std)
print normalized.shape
normalized.head()
# Out:
# (2424, 157)
#            family_ALS_hist_last  Hematocrit_mean  Hematocrit_pct_diff  \
# SubjectID
# 533                           0                0                    0
# 1234                          0                0                    0
# 5588                          0                0                    0
# 7399                          0                0                    0
# 7799                          0                0                    0
#
#            Hematocrit_last  Hematocrit_mean_slope  weight_mean  \
# SubjectID
# 533                      0                      0            0
# 1234                     0                      0            0
# 5588                     0                      0            0
# 7399                     0                      0            0
# 7799                     0                      0            0
#
#            weight_pct_diff  weight_last  weight_mean_slope  Sodium_mean  \
# SubjectID
# 533                      0            0                  0            0
# 1234                     0            0                  0            0
# 5588                     0            0                  0            0
# 7399                     0            0                  0            0
# 7799                     0            0                  0            0
#
#                    ...           Absolute Basophil Count_last  \
# SubjectID          ...
# 533                ...                                      0
# 1234               ...                                      0
# 5588               ...                                      0
# 7399               ...                                      0
# 7799               ...                                      0
#
#            Absolute Basophil Count_mean_slope  Protein_mean  Protein_pct_diff  \
# SubjectID
# 533                                         0             0                 0
# 1234                                        0             0                 0
# 5588                                        0             0                 0
# 7399                                        0             0                 0
# 7799                                        0             0                 0
#
#            Protein_last  Protein_mean_slope  ALT(SGPT)_mean  \
# SubjectID
# 533                   0                   0               0
# 1234                  0                   0               0
# 5588                  0                   0               0
# 7399                  0                   0               0
# 7799                  0                   0               0
#
#            ALT(SGPT)_pct_diff  ALT(SGPT)_last  ALT(SGPT)_mean_slope
# SubjectID
# 533                         0               0                     0
# 1234                        0               0                     0
# 5588                        0               0                     0
# 7399                        0               0                     0
# 7799                        0               0                     0
#
# [5 rows x 157 columns]

# %%
normalized.describe().T.sort("std", ascending=False)
# Out:
#                                       count          mean       std  \
# mouth_mean                             2424  3.331402e-15  0.999794
# mouth_last                             2424 -6.012884e-15  0.999794
# onset_delta_last                       2424  1.325489e-16  0.998761
# mouth_mean_slope                       2424  6.870650e-16  0.997107
# mouth_pct_diff                         2424  2.649146e-15  0.996693
# ALSFRS_Total_last                      2424  8.609096e-03  0.971562
# ALSFRS_Total_mean                      2424  1.015268e-02  0.969786
# hands_last                             2424  9.945373e-03  0.967065
# hands_mean                             2424  1.112791e-02  0.965834
# ALSFRS_Total_mean_slope                2424 -3.429735e-03  0.961809
# ALSFRS_Total_pct_diff                  2424 -1.327045e-03  0.960417
# fvc_percent_mean_slope                 2424 -9.403956e-04  0.947606
# fvc_percent_pct_diff                   2424  8.408349e-04  0.946271
# fvc_percent_last                       2424  1.548897e-02  0.942307
# fvc_percent_mean                       2424  1.867446e-02  0.941384
# hands_mean_slope                       2424  2.331344e-03  0.925017
# Creatinine_pct_diff                    2424  1.262862e-02  0.924500
# hands_pct_diff                         2424  9.038820e-03  0.785581
# respiratory_pct_diff                   2424  4.867873e-02  0.749585
# respiratory_mean_slope                 2424  5.621654e-02  0.689399
# Creatinine_mean_slope                  2424 -2.447593e-02  0.671794
# respiratory_mean                       2424  1.720873e-01  0.595308
# respiratory_last                       2424  1.823893e-01  0.553671
# Creatinine_mean                        2424 -6.929900e-02  0.549679
# Creatinine_last                        2424 -7.507759e-02  0.540096
# weight_last                            2424 -5.935927e-04  0.232058
# weight_mean                            2424 -7.105393e-04  0.230397
# Chloride_pct_diff                      2424 -7.605614e-03  0.221219
# Chloride_mean                          2424  1.832976e-03  0.220101
# Chloride_last                          2424 -9.229254e-04  0.217540
# ...                                     ...           ...       ...
# Phosphorus_mean_slope                  2424  0.000000e+00  0.000000
# Calcium_mean                           2424  0.000000e+00  0.000000
# respiratory_rate_mean_slope            2424  0.000000e+00  0.000000
# respiratory_rate_last                  2424  0.000000e+00  0.000000
# respiratory_rate_pct_diff              2424  0.000000e+00  0.000000
# respiratory_rate_mean                  2424  0.000000e+00  0.000000
# Age_last                               2424  0.000000e+00  0.000000
# M                                      2424  0.000000e+00  0.000000
# F                                      2424  0.000000e+00  0.000000
# Hematocrit_mean                        2424  0.000000e+00  0.000000
# CK_mean_slope                          2424  0.000000e+00  0.000000
# CK_last                                2424  0.000000e+00  0.000000
# CK_pct_diff                            2424  0.000000e+00  0.000000
# CK_mean                                2424  0.000000e+00  0.000000
# Phosphorus_last                        2424  0.000000e+00  0.000000
# bp_diastolic_mean                      2424  0.000000e+00  0.000000
# Phosphorus_pct_diff                    2424  0.000000e+00  0.000000
# Phosphorus_mean                        2424  0.000000e+00  0.000000
# Blood Urea Nitrogen (BUN)_mean_slope   2424  0.000000e+00  0.000000
# Blood Urea Nitrogen (BUN)_last         2424  0.000000e+00  0.000000
# Blood Urea Nitrogen (BUN)_pct_diff     2424  0.000000e+00  0.000000
# Blood Urea Nitrogen (BUN)_mean         2424  0.000000e+00  0.000000
# Red Blood Cells (RBC)_mean_slope       2424  0.000000e+00  0.000000
# Red Blood Cells (RBC)_last             2424  0.000000e+00  0.000000
# Red Blood Cells (RBC)_pct_diff         2424  0.000000e+00  0.000000
# Red Blood Cells (RBC)_mean             2424  0.000000e+00  0.000000
# bp_diastolic_mean_slope                2424  0.000000e+00  0.000000
# bp_diastolic_last                      2424  0.000000e+00  0.000000
# bp_diastolic_pct_diff                  2424  0.000000e+00  0.000000
# ALT(SGPT)_mean_slope                   2424  0.000000e+00  0.000000
#
#                                             min       25%       50%       75%  \
# mouth_mean                            -4.755964 -0.608246  0.428683  0.774327
# mouth_last                            -4.285426 -0.501320  0.339593  0.760049
# onset_delta_last                      -5.868302 -0.511828  0.271135  0.750684
# mouth_mean_slope                      -8.990357 -0.183935  0.085344  0.085344
# mouth_pct_diff                       -12.556495 -0.186034  0.091954  0.091954
# ALSFRS_Total_last                     -3.827927 -0.449770  0.056953  0.732585
# ALSFRS_Total_mean                     -3.728697 -0.550589  0.121703  0.717598
# hands_last                            -2.477562 -0.251706  0.193465  0.638636
# hands_mean                            -2.750180 -0.466795  0.134096  0.855164
# ALSFRS_Total_mean_slope               -5.675564 -0.318257  0.014387  0.243993
# ALSFRS_Total_pct_diff                 -6.547038 -0.288952  0.040889  0.266326
# fvc_percent_mean_slope               -10.115168 -0.239236  0.000000  0.252009
# fvc_percent_pct_diff                 -11.869833 -0.192292  0.000000  0.252392
# fvc_percent_last                      -4.209979 -0.495158  0.000000  0.590306
# fvc_percent_mean                      -3.877947 -0.529281  0.000000  0.605045
# hands_mean_slope                     -10.011314 -0.156421  0.155725  0.155725
# Creatinine_pct_diff                   -0.033857 -0.019951  0.000000  0.000000
# hands_pct_diff                       -13.236799 -0.150664  0.157245  0.157245
# respiratory_pct_diff                  -4.121627  0.000000  0.004858  0.004858
# respiratory_mean_slope                -4.473866  0.000000  0.056652  0.056652
# Creatinine_mean_slope                -17.645697  0.000000  0.000000  0.000000
# respiratory_mean                      -3.917850  0.000000  0.000000  0.647111
# respiratory_last                      -3.049000  0.000000  0.566232  0.566232
# Creatinine_mean                       -2.921525  0.000000  0.000000  0.000000
# Creatinine_last                       -3.683838  0.000000  0.000000  0.000000
# weight_last                           -2.405946  0.000000  0.000000  0.000000
# weight_mean                           -2.346995  0.000000  0.000000  0.000000
# Chloride_pct_diff                     -6.166689  0.000000  0.000000  0.000000
# Chloride_mean                         -5.349826  0.000000  0.000000  0.000000
# Chloride_last                         -3.897132  0.000000  0.000000  0.000000
# ...                                         ...       ...       ...       ...
# Phosphorus_mean_slope                  0.000000  0.000000  0.000000  0.000000
# Calcium_mean                           0.000000  0.000000  0.000000  0.000000
# respiratory_rate_mean_slope            0.000000  0.000000  0.000000  0.000000
# respiratory_rate_last                  0.000000  0.000000  0.000000  0.000000
# respiratory_rate_pct_diff              0.000000  0.000000  0.000000  0.000000
# respiratory_rate_mean                  0.000000  0.000000  0.000000  0.000000
# Age_last                               0.000000  0.000000  0.000000  0.000000
# M                                      0.000000  0.000000  0.000000  0.000000
# F                                      0.000000  0.000000  0.000000  0.000000
# Hematocrit_mean                        0.000000  0.000000  0.000000  0.000000
# CK_mean_slope                          0.000000  0.000000  0.000000  0.000000
# CK_last                                0.000000  0.000000  0.000000  0.000000
# CK_pct_diff                            0.000000  0.000000  0.000000  0.000000
# CK_mean                                0.000000  0.000000  0.000000  0.000000
# Phosphorus_last                        0.000000  0.000000  0.000000  0.000000
# bp_diastolic_mean                      0.000000  0.000000  0.000000  0.000000
# Phosphorus_pct_diff                    0.000000  0.000000  0.000000  0.000000
# Phosphorus_mean                        0.000000  0.000000  0.000000  0.000000
# Blood Urea Nitrogen (BUN)_mean_slope   0.000000  0.000000  0.000000  0.000000
# Blood Urea Nitrogen (BUN)_last         0.000000  0.000000  0.000000  0.000000
# Blood Urea Nitrogen (BUN)_pct_diff     0.000000  0.000000  0.000000  0.000000
# Blood Urea Nitrogen (BUN)_mean         0.000000  0.000000  0.000000  0.000000
# Red Blood Cells (RBC)_mean_slope       0.000000  0.000000  0.000000  0.000000
# Red Blood Cells (RBC)_last             0.000000  0.000000  0.000000  0.000000
# Red Blood Cells (RBC)_pct_diff         0.000000  0.000000  0.000000  0.000000
# Red Blood Cells (RBC)_mean             0.000000  0.000000  0.000000  0.000000
# bp_diastolic_mean_slope                0.000000  0.000000  0.000000  0.000000
# bp_diastolic_last                      0.000000  0.000000  0.000000  0.000000
# bp_diastolic_pct_diff                  0.000000  0.000000  0.000000  0.000000
# ALT(SGPT)_mean_slope                   0.000000  0.000000  0.000000  0.000000
#
#                                             max
# mouth_mean                             0.774327
# mouth_last                             0.760049
# onset_delta_last                       1.618698
# mouth_mean_slope                      15.643688
# mouth_pct_diff                        26.111621
# ALSFRS_Total_last                      1.746032
# ALSFRS_Total_mean                      1.771874
# hands_last                             1.083807
# hands_mean                             1.095521
# ALSFRS_Total_mean_slope               23.211877
# ALSFRS_Total_pct_diff                 23.332401
# fvc_percent_mean_slope                11.766291
# fvc_percent_pct_diff                  14.472155
# fvc_percent_last                       4.637494
# fvc_percent_mean                       4.042697
# hands_mean_slope                      12.017270
# Creatinine_pct_diff                   45.508135
# hands_pct_diff                         8.988483
# respiratory_pct_diff                  25.680768
# respiratory_mean_slope                21.199067
# Creatinine_mean_slope                  4.796415
# respiratory_mean                       0.647111
# respiratory_last                       0.566232
# Creatinine_mean                        3.429083
# Creatinine_last                        3.865581
# weight_last                            2.728387
# weight_mean                            2.747435
# Chloride_pct_diff                      2.150683
# Chloride_mean                          2.400597
# Chloride_last                          2.262492
# ...                                         ...
# Phosphorus_mean_slope                  0.000000
# Calcium_mean                           0.000000
# respiratory_rate_mean_slope            0.000000
# respiratory_rate_last                  0.000000
# respiratory_rate_pct_diff              0.000000
# respiratory_rate_mean                  0.000000
# Age_last                               0.000000
# M                                      0.000000
# F                                      0.000000
# Hematocrit_mean                        0.000000
# CK_mean_slope                          0.000000
# CK_last                                0.000000
# CK_pct_diff                            0.000000
# CK_mean                                0.000000
# Phosphorus_last                        0.000000
# bp_diastolic_mean                      0.000000
# Phosphorus_pct_diff                    0.000000
# Phosphorus_mean                        0.000000
# Blood Urea Nitrogen (BUN)_mean_slope   0.000000
# Blood Urea Nitrogen (BUN)_last         0.000000
# Blood Urea Nitrogen (BUN)_pct_diff     0.000000
# Blood Urea Nitrogen (BUN)_mean         0.000000
# Red Blood Cells (RBC)_mean_slope       0.000000
# Red Blood Cells (RBC)_last             0.000000
# Red Blood Cells (RBC)_pct_diff         0.000000
# Red Blood Cells (RBC)_mean             0.000000
# bp_diastolic_mean_slope                0.000000
# bp_diastolic_last                      0.000000
# bp_diastolic_pct_diff                  0.000000
# ALT(SGPT)_mean_slope                   0.000000
#
# [157 rows x 8 columns]

# %%
slope = pd.read_csv('../all_slope.csv', sep = '|', index_col="SubjectID")
clusters = pd.read_csv('../all_kmeans_clusters.csv', sep = '|', index_col="SubjectID")

clusters.index = clusters.index.astype(str)
slope.index = slope.index.astype(str)
normalized.index = normalized.index.astype(str)

X = normalized.join(clusters)
Y = slope.join(clusters)

print Y.shape, X.shape, clusters.shape
display(Y.head(3))
# Out:
# (2424, 2) (2424, 158) (2424, 1)
#            ALSFRS_slope  cluster
# SubjectID
# 533           -0.965608        0
# 649           -0.921717        2
# 1234          -0.914787        0

# %% [markdown]
# ## Train a prediction model per cluster

# %%
from sklearn import linear_model
import numpy as np

def get_model_per_cluster(X, Y):
    model_per_cluster = {}
    for c in X.cluster.unique():    
        X_cluster = X[X.cluster==c]
        Y_cluster = Y[Y.cluster == c].ALSFRS_slope
        regr = linear_model.LinearRegression()
        regr.fit(X_cluster, Y_cluster)

        print 'cluster: %d size: %s' % (c, Y_cluster.shape)
        print "\t RMS error (0 is perfect): %.2f" % np.sqrt(np.mean(
            (regr.predict(X_cluster) - Y_cluster) ** 2))
        print('\t explained variance score (1 is perfect): %.2f' % regr.score(X_cluster, Y_cluster))
        print "3 sample predictions: ", regr.predict(X_cluster)[:3]
        model_per_cluster[c] = {"train_data_means": X_cluster.mean(), "model" : regr}
    return model_per_cluster

model_per_cluster = get_model_per_cluster(X, Y)
# Out:
# cluster: 0 size: (775L,)
# 	 RMS error (0 is perfect): 0.56
# 	 explained variance score (1 is perfect): 0.18
# 3 sample predictions:  [-0.90697593 -0.51335769 -0.83928496]
# cluster: 1 size: (117L,)
# 	 RMS error (0 is perfect): 0.53
# 	 explained variance score (1 is perfect): 0.36
# 3 sample predictions:  [-0.49043559 -0.89818179 -1.00308666]
# cluster: 2 size: (1532L,)
# 	 RMS error (0 is perfect): 0.55
# 	 explained variance score (1 is perfect): 0.22
# 3 sample predictions:  [-0.8197925  -0.7681308   0.11353219]

# %%
with open("../model_per_cluster.pickle", "wb") as output_file:
    pickle.dump(model_per_cluster, output_file)

# %% [markdown]
# ## Apply the model on both `train` and `test`

# %%
for t in ['all', 'test']:
    print t
    df = pd.read_csv('../' + t + '_data_selected.csv', sep='|', index_col=False, dtype="unicode")
    vectorized, _ = vectorize(df, all_feature_metadata)
    normalized, _ = normalize(vectorized, all_feature_metadata, train_data_means, train_data_std)
    clusters = pd.read_csv('../' + t + '_kmeans_clusters.csv', sep = '|', index_col=0)

    clusters.index = clusters.index.astype(str)
    normalized.index = normalized.index.astype(str)

    X = normalized.join(clusters)
    pred = X.apply(apply_model, args=[model_per_cluster], axis = 1)
    pred.to_csv('../' + t + '_prediction.csv',sep='|')

pred.head()
