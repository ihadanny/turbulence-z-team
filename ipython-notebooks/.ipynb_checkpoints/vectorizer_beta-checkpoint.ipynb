# %% [markdown]
# ## Builds a model for vectorizing the raw data (apply it once on train and once on test) :
# * pivot from the initial feature_name:feature_value form to a vector
# * handle dummy variables: translate categoric variables into N-1 dummy variables (The model is based on categories in train data)
# * handle time-series variables: reduce them in several hard-coded methods
# * fill missing values with train data means, and normalize to z-scores with train data std

# %%
from IPython.display import display

import pandas as pd
import numpy as np
import pickle
from collections import defaultdict
from vectorizing_funcs import *

# %%
df = pd.read_csv('../all_data.csv', sep = '|', error_bad_lines=False, index_col=False, dtype='unicode')
df.head()
# Out:
#   SubjectID    form_name feature_name feature_value feature_unit feature_delta
# 0       533  Demographic       Gender             F          NaN           0.0
# 1       533  Demographic          Age            65          NaN           0.0
# 2       533  Demographic         Race         White          NaN           0.0
# 3       533        ALSHX  onset_delta         -1023          NaN           0.0
# 4       533        ALSHX   diag_delta           -44          NaN           0.0

# %% [markdown]
# # Build metadata: assign features to vectorizing functions
# funcs_to_features arrays define pairs of funcs (can be a list of functions or a single one) and features that should get these functions calculated. Overlapping is allowed.
#
# There is a list for time-series functions (as described before) and for dummy functions. Both are inverted to feature_to_funcs maps.

# %%
ts_funcs_to_features = add_frequent_lab_tests_to_ts_features(df, ts_funcs_to_features)    
all_feature_metadata = invert_func_to_features(ts_funcs_to_features, "ts")
all_feature_metadata.update(invert_func_to_features(dummy_funcs_to_features, "dummy"))

# %% [markdown]
# ## Learn to_dummies model
# Which kind of categories do we have available in our train data?

# %%
all_feature_metadata = learn_to_dummies_model(df, all_feature_metadata)

# %% [markdown]
# ##Vectorize `train` data

# %%
vectorized, all_feature_metadata = vectorize(df, all_feature_metadata, debug=True)
vectorized.head()
# Out:
# family_ALS_hist
# onset_site
# weight
# Sodium
# hands
# pulse
# White Blood Cell (WBC)
# Albumin
# Chloride
# ALSFRS_Total
# Glucose
# Alkaline Phosphatase
# bp_systolic
# fvc_percent
# Potassium
# BMI
# bp_diastolic
# Blood Urea Nitrogen (BUN)
# Phosphorus
# CK
# Gender
# Age
# respiratory_rate
# Calcium
# Race
# mouth
# Gamma-glutamyltransferase
# Total Cholesterol
# onset_delta
# Bilirubin (Total)
# Creatinine
# temperature
# respiratory
# AST(SGOT)
# Hemoglobin
# Platelets
# if_use_Riluzole
# Protein
# ALT(SGPT)
#            family_ALS_hist_last  Bulbar  Limb  Limb and Bulbar  weight_last  \
# SubjectID
# 533                         NaN       1     0                0         50.5
# 649                         NaN       1     0                0         74.4
# 1234                        NaN       1     0                0         96.0
# 2492                        NaN       0     1                0         90.1
# 2956                        NaN       0     1                0         65.3
#
#            weight_mean_slope  weight_mean  weight_pct_diff  Sodium_last  \
# SubjectID
# 533                 0.004337    51.000000        -0.000108          146
# 649                 0.035425    74.566667         0.000156          136
# 1234                0.012698    95.050000         0.000227          142
# 2492                0.000000    90.100000         0.000000          139
# 2956               -0.032251    65.100000        -0.000059          142
#
#            Sodium_mean_slope         ...          Platelets_pct_diff  \
# SubjectID                            ...
# 533                 0.032967         ...                   -0.001105
# 649                 0.092037         ...                   -0.002510
# 1234               -0.095671         ...                   -0.000532
# 2492                0.029412         ...                         NaN
# 2956                0.012987         ...                    0.000281
#
#            if_use_Riluzole_last  Protein_last  Protein_mean_slope  \
# SubjectID
# 533                         NaN            69           -0.010989
# 649                           1            73            0.058039
# 1234                          1            72           -0.181530
# 2492                        NaN           NaN                 NaN
# 2956                          0            75            0.096681
#
#            Protein_mean  Protein_pct_diff  ALT(SGPT)_last  \
# SubjectID
# 533                69.5         -0.000157              24
# 649                71.0          0.000549              25
# 1234               74.5         -0.001099              24
# 2492                NaN               NaN              62
# 2956               73.5          0.000732              28
#
#            ALT(SGPT)_mean_slope  ALT(SGPT)_mean  ALT(SGPT)_pct_diff
# SubjectID
# 533                    0.065934           21.00            0.003663
# 649                   -0.072383           17.00            0.007212
# 1234                  -0.100577           22.75            0.000621
# 2492                   0.058824           61.00            0.000980
# 2956                  -0.050505           25.25            0.001558
#
# [5 rows x 140 columns]

# %%
vectorized.describe().transpose().sort("count", ascending=True)
# Out:
#                                       count        mean         std  \
# family_ALS_hist_last                    346    0.208092    0.406531
# temperature_pct_diff                    454    0.000047    0.001412
# temperature_mean_slope                  454    0.000713    0.056535
# temperature_mean                        457   36.563308    0.755195
# temperature_last                        457   36.654184    2.948809
# BMI_last                               1280    0.002577    0.000436
# CK_pct_diff                            1423    0.005245    0.012222
# CK_mean_slope                          1423    1.293199   10.441481
# Gamma-glutamyltransferase_mean_slope   1539    0.017835    0.942537
# Gamma-glutamyltransferase_pct_diff     1539    0.001713    0.007553
# Total Cholesterol_pct_diff             1540    0.000511    0.012599
# Total Cholesterol_mean_slope           1540   -0.000236    0.032043
# Platelets_mean_slope                   1575   -0.461050    2.088658
# Platelets_pct_diff                     1575   -0.000338    0.002391
# Protein_mean_slope                     1586   -0.033384    0.402483
# Phosphorus_mean_slope                  1586    0.000175    0.011066
# Protein_pct_diff                       1586   -0.000086    0.001436
# Phosphorus_pct_diff                    1586    0.000239    0.002841
# Alkaline Phosphatase_mean_slope        1587   -0.423126    3.271955
# Alkaline Phosphatase_pct_diff          1587    0.000285    0.003382
# Calcium_pct_diff                       1587    0.000207    0.004179
# Calcium_mean_slope                     1587    0.000196    0.012138
# Albumin_mean_slope                     1587   -0.027581    0.238752
# Albumin_pct_diff                       1587   -0.000131    0.001160
# White Blood Cell (WBC)_mean_slope      1673   -0.008650    0.084366
# White Blood Cell (WBC)_pct_diff        1673    0.000364    0.003713
# Hemoglobin_pct_diff                    1679    0.000203    0.004865
# Hemoglobin_mean_slope                  1679   -0.030401    0.820680
# Glucose_mean_slope                     1683    0.024840    0.109263
# Glucose_pct_diff                       1683    0.071446    0.283593
# ...                                     ...         ...         ...
# mouth_pct_diff                         2193   -0.000257    0.003283
# hands_mean_slope                       2194   -0.003963    0.027231
# ALSFRS_Total_pct_diff                  2194   -0.000538    0.002253
# mouth_mean_slope                       2194   -0.002063    0.027183
# ALSFRS_Total_mean_slope                2194   -0.015535    0.071764
# respiratory_pct_diff                   2194    0.000037    0.004466
# respiratory_mean_slope                 2194   -0.000737    0.015915
# onset_delta_last                       2199 -693.467030  416.873261
# hands_last                             2204    5.661071    2.169175
# ALSFRS_Total_mean                      2204   30.705800    5.208224
# mouth_last                             2204   10.313521    2.260032
# mouth_mean                             2204   10.425363    2.066119
# ALSFRS_Total_last                      2204   30.097550    5.607531
# hands_mean                             2204    5.800688    2.015350
# respiratory_mean                       2204    3.733606    0.429243
# respiratory_last                       2204    3.709619    0.539900
# Limb                                   2205    0.791837    0.406086
# Bulbar                                 2205    0.200907    0.400770
# Limb and Bulbar                        2205    0.007256    0.084893
# Age_last                               2205   54.254422   11.481625
# weight_mean                            2205   76.212686   15.651059
# M                                      2205    0.641723    0.479603
# White                                  2205    0.953288    0.211069
# Other                                  2205    0.003628    0.060138
# Hispanic                               2205    0.004535    0.067206
# Black                                  2205    0.012698    0.111995
# Asian                                  2205    0.007256    0.084893
# F                                      2205    0.358277    0.479603
# weight_last                            2205   76.295739   15.753842
# Unknown                                2205    0.018594    0.135117
#
#                                               min         25%         50%  \
# family_ALS_hist_last                     0.000000    0.000000    0.000000
# temperature_pct_diff                    -0.001936   -0.000190    0.000000
# temperature_mean_slope                  -0.200714   -0.013833   -0.002532
# temperature_mean                        31.700000   36.333333   36.580000
# temperature_last                        34.500000   36.200000   36.600000
# BMI_last                                 0.001528    0.002267    0.002518
# CK_pct_diff                             -0.039435   -0.000822    0.002551
# CK_mean_slope                          -66.363194   -0.492879    0.577354
# Gamma-glutamyltransferase_mean_slope   -14.450537   -0.071429    0.030719
# Gamma-glutamyltransferase_pct_diff      -0.026243   -0.001616    0.000442
# Total Cholesterol_pct_diff              -0.007897   -0.000725    0.000103
# Total Cholesterol_mean_slope            -0.400891   -0.009675    0.000877
# Platelets_mean_slope                   -31.814143   -0.768935   -0.168185
# Platelets_pct_diff                      -0.031321   -0.001381   -0.000343
# Protein_mean_slope                      -5.015152   -0.093784   -0.016704
# Phosphorus_mean_slope                   -0.184518   -0.002866    0.000261
# Protein_pct_diff                        -0.009785   -0.000603   -0.000157
# Phosphorus_pct_diff                     -0.032520   -0.001161    0.000000
# Alkaline Phosphatase_mean_slope        -48.357143   -0.165026    0.028510
# Alkaline Phosphatase_pct_diff           -0.022361   -0.001101    0.000392
# Calcium_pct_diff                        -0.011762   -0.000476   -0.000100
# Calcium_mean_slope                      -0.159753   -0.002148   -0.000306
# Albumin_mean_slope                      -5.317647   -0.063889   -0.013639
# Albumin_pct_diff                        -0.009042   -0.000689   -0.000189
# White Blood Cell (WBC)_mean_slope       -1.061943   -0.022513    0.000778
# White Blood Cell (WBC)_pct_diff         -0.040821   -0.001428    0.000067
# Hemoglobin_pct_diff                     -0.010546   -0.000438    0.000000
# Hemoglobin_mean_slope                   -4.013049   -0.148040   -0.021978
# Glucose_mean_slope                      -1.167996   -0.009936    0.004760
# Glucose_pct_diff                        -0.020779   -0.001102    0.000333
# ...                                           ...         ...         ...
# mouth_pct_diff                          -0.041667    0.000000    0.000000
# hands_mean_slope                        -0.333333   -0.008929    0.000000
# ALSFRS_Total_pct_diff                   -0.015385   -0.001229   -0.000410
# mouth_mean_slope                        -0.250000   -0.005926    0.000000
# ALSFRS_Total_mean_slope                 -0.428571   -0.040544   -0.011340
# respiratory_pct_diff                    -0.041667    0.000000    0.000000
# respiratory_mean_slope                  -0.148352    0.000000    0.000000
# onset_delta_last                     -3119.000000 -911.000000 -582.000000
# hands_last                               0.000000    4.000000    6.000000
# ALSFRS_Total_mean                       12.000000   27.666667   31.500000
# mouth_last                               0.000000    9.000000   11.000000
# mouth_mean                               1.000000    9.333333   11.333333
# ALSFRS_Total_last                        9.000000   27.000000   31.000000
# hands_mean                               0.000000    4.750000    6.000000
# respiratory_mean                         1.000000    3.500000    4.000000
# respiratory_last                         0.000000    3.000000    4.000000
# Limb                                     0.000000    1.000000    1.000000
# Bulbar                                   0.000000    0.000000    0.000000
# Limb and Bulbar                          0.000000    0.000000    0.000000
# Age_last                                18.000000   46.000000   55.000000
# weight_mean                             39.180000   64.666667   75.000000
# M                                        0.000000    0.000000    1.000000
# White                                    0.000000    1.000000    1.000000
# Other                                    0.000000    0.000000    0.000000
# Hispanic                                 0.000000    0.000000    0.000000
# Black                                    0.000000    0.000000    0.000000
# Asian                                    0.000000    0.000000    0.000000
# F                                        0.000000    0.000000    0.000000
# weight_last                             38.000000   64.900000   75.300000
# Unknown                                  0.000000    0.000000    0.000000
#
#                                              75%         max
# family_ALS_hist_last                    0.000000    1.000000
# temperature_pct_diff                    0.000101    0.026853
# temperature_mean_slope                  0.007399    0.909242
# temperature_mean                       36.800000   49.240000
# temperature_last                       36.900000   98.600000
# BMI_last                                0.002826    0.004731
# CK_pct_diff                             0.007517    0.171150
# CK_mean_slope                           2.311193  249.280809
# Gamma-glutamyltransferase_mean_slope    0.167995   12.385714
# Gamma-glutamyltransferase_pct_diff      0.003206    0.155012
# Total Cholesterol_pct_diff              0.001093    0.489659
# Total Cholesterol_mean_slope            0.012007    0.257497
# Platelets_mean_slope                    0.263692   14.468277
# Platelets_pct_diff                      0.000687    0.012671
# Protein_mean_slope                      0.055799    7.115143
# Phosphorus_mean_slope                   0.003203    0.075546
# Protein_pct_diff                        0.000335    0.044355
# Phosphorus_pct_diff                     0.001433    0.054983
# Alkaline Phosphatase_mean_slope         0.217795    8.039264
# Alkaline Phosphatase_pct_diff           0.001827    0.032230
# Calcium_pct_diff                        0.000261    0.116849
# Calcium_mean_slope                      0.001559    0.321093
# Albumin_mean_slope                      0.035649    1.504023
# Albumin_pct_diff                        0.000353    0.015873
# White Blood Cell (WBC)_mean_slope       0.019827    0.414977
# White Blood Cell (WBC)_pct_diff         0.001832    0.050000
# Hemoglobin_pct_diff                     0.000362    0.128630
# Hemoglobin_mean_slope                   0.087481   27.521521
# Glucose_mean_slope                      0.026154    1.096363
# Glucose_pct_diff                        0.002412    1.967372
# ...                                          ...         ...
# mouth_pct_diff                          0.000000    0.085714
# hands_mean_slope                        0.000000    0.333333
# ALSFRS_Total_pct_diff                   0.000000    0.052083
# mouth_mean_slope                        0.000000    0.428571
# ALSFRS_Total_mean_slope                 0.004955    1.666667
# respiratory_pct_diff                    0.000000    0.111111
# respiratory_mean_slope                  0.000000    0.333333
# onset_delta_last                     -376.000000  -16.000000
# hands_last                              8.000000    8.000000
# ALSFRS_Total_mean                      34.500000   40.000000
# mouth_last                             12.000000   12.000000
# mouth_mean                             12.000000   12.000000
# ALSFRS_Total_last                      34.000000   40.000000
# hands_mean                              7.666667    8.000000
# respiratory_mean                        4.000000    4.000000
# respiratory_last                        4.000000    4.000000
# Limb                                    1.000000    1.000000
# Bulbar                                  0.000000    1.000000
# Limb and Bulbar                         0.000000    1.000000
# Age_last                               63.000000   80.000000
# weight_mean                            85.750000  148.300000
# M                                       1.000000    1.000000
# White                                   1.000000    1.000000
# Other                                   0.000000    1.000000
# Hispanic                                0.000000    1.000000
# Black                                   0.000000    1.000000
# Asian                                   0.000000    1.000000
# F                                       1.000000    1.000000
# weight_last                            86.000000  147.500000
# Unknown                                 0.000000    1.000000
#
# [140 rows x 8 columns]

# %% [markdown]
# ## Filling empty values with means and normalizing
# - NOTE that we have to use the `train` data means and std

# %%
train_data_means = vectorized.mean()
train_data_std = vectorized.std()            
normalized, all_feature_metadata = normalize(vectorized, all_feature_metadata, train_data_means, train_data_std)
normalized.describe().T.sort("std", ascending=True)
# Out:
#                                       count          mean       std  \
# family_ALS_hist_last                   2205 -9.566548e-18  0.395643
# temperature_mean_slope                 2205  5.538528e-19  0.453360
# temperature_pct_diff                   2205  9.616898e-18  0.453360
# temperature_last                       2205 -7.835506e-16  0.454859
# temperature_mean                       2205  4.660721e-15  0.454859
# BMI_last                               2205  5.547087e-16  0.761780
# CK_mean_slope                          2205  7.112524e-17  0.803238
# CK_pct_diff                            2205  7.411557e-17  0.803238
# Gamma-glutamyltransferase_mean_slope   2205  4.330122e-18  0.835357
# Gamma-glutamyltransferase_pct_diff     2205  1.346869e-16  0.835357
# Total Cholesterol_pct_diff             2205  4.502571e-17  0.835629
# Total Cholesterol_mean_slope           2205  7.250436e-18  0.835629
# Platelets_pct_diff                     2205 -5.609018e-17  0.845078
# Platelets_mean_slope                   2205 -1.587795e-16  0.845078
# Protein_pct_diff                       2205  4.043125e-17  0.848025
# Protein_mean_slope                     2205  9.212837e-17  0.848025
# Phosphorus_mean_slope                  2205 -5.128173e-17  0.848025
# Phosphorus_pct_diff                    2205  4.662433e-17  0.848025
# Calcium_pct_diff                       2205  4.449113e-17  0.848293
# Alkaline Phosphatase_pct_diff          2205 -2.306041e-17  0.848293
# Calcium_mean_slope                     2205 -5.186076e-17  0.848293
# Alkaline Phosphatase_mean_slope        2205  4.194176e-17  0.848293
# Albumin_pct_diff                       2205 -2.117417e-16  0.848293
# Albumin_mean_slope                     2205  1.380352e-16  0.848293
# White Blood Cell (WBC)_pct_diff        2205 -6.059653e-17  0.870988
# White Blood Cell (WBC)_mean_slope      2205 -5.201181e-17  0.870988
# Hemoglobin_pct_diff                    2205 -2.463701e-17  0.872550
# Hemoglobin_mean_slope                  2205 -5.926854e-17  0.872550
# Glucose_pct_diff                       2205  9.632003e-17  0.873589
# Glucose_mean_slope                     2205 -3.297816e-16  0.873589
# ...                                     ...           ...       ...
# mouth_pct_diff                         2205 -2.480253e-16  0.997274
# respiratory_pct_diff                   2205  3.247749e-17  0.997501
# respiratory_mean_slope                 2205 -1.724559e-16  0.997501
# ALSFRS_Total_pct_diff                  2205  1.006124e-16  0.997501
# mouth_mean_slope                       2205  7.673378e-17  0.997501
# ALSFRS_Total_mean_slope                2205 -2.107064e-16  0.997501
# hands_mean_slope                       2205  8.708076e-17  0.997501
# onset_delta_last                       2205 -9.606828e-17  0.998638
# respiratory_mean                       2205 -2.337460e-15  0.999773
# hands_mean                             2205 -2.937635e-15  0.999773
# respiratory_last                       2205 -6.807354e-17  0.999773
# mouth_mean                             2205 -2.024080e-17  0.999773
# ALSFRS_Total_last                      2205 -3.200262e-16  0.999773
# ALSFRS_Total_mean                      2205  2.249649e-16  0.999773
# mouth_last                             2205  6.394482e-17  0.999773
# hands_last                             2205  1.684216e-16  0.999773
# Bulbar                                 2205 -5.598948e-17  1.000000
# Black                                  2205  1.767042e-16  1.000000
# White                                  2205 -2.074179e-16  1.000000
# Unknown                                2205 -6.223291e-17  1.000000
# Limb                                   2205 -2.678633e-17  1.000000
# Other                                  2205 -4.475067e-16  1.000000
# Asian                                  2205  3.104219e-16  1.000000
# weight_mean                            2205  4.485301e-15  1.000000
# weight_last                            2205  2.894686e-15  1.000000
# Age_last                               2205  2.294461e-16  1.000000
# Limb and Bulbar                        2205 -1.305708e-16  1.000000
# Hispanic                               2205 -4.744504e-16  1.000000
# M                                      2205  1.054334e-16  1.000000
# F                                      2205 -1.054334e-16  1.000000
#
#                                             min       25%       50%       75%  \
# family_ALS_hist_last                  -0.511873  0.000000  0.000000  0.000000
# temperature_mean_slope                -3.562848  0.000000  0.000000  0.000000
# temperature_pct_diff                  -1.403764  0.000000  0.000000  0.000000
# temperature_last                      -0.730527  0.000000  0.000000  0.000000
# temperature_mean                      -6.439803  0.000000  0.000000  0.000000
# BMI_last                              -2.405262 -0.276883  0.000000  0.057740
# CK_mean_slope                         -6.479578 -0.110630  0.000000  0.000000
# CK_pct_diff                           -3.655582 -0.345987  0.000000  0.000000
# Gamma-glutamyltransferase_mean_slope -15.350453 -0.037447  0.000000  0.075386
# Gamma-glutamyltransferase_pct_diff    -3.701246 -0.331812  0.000000  0.013115
# Total Cholesterol_pct_diff            -0.667319 -0.068817  0.000000  0.008061
# Total Cholesterol_mean_slope         -12.503481 -0.134478  0.000000  0.218261
# Platelets_pct_diff                   -12.959647 -0.243795  0.000000  0.230793
# Platelets_mean_slope                 -15.011120 -0.004245  0.000000  0.259943
# Protein_pct_diff                      -6.753089 -0.230995  0.000000  0.166560
# Protein_mean_slope                   -12.377586 -0.063468  0.000000  0.142102
# Phosphorus_mean_slope                -16.690396 -0.164070  0.000000  0.149287
# Phosphorus_pct_diff                  -11.530324 -0.306101  0.000000  0.221448
# Calcium_pct_diff                      -2.864150 -0.123045 -0.005941  0.000000
# Alkaline Phosphatase_pct_diff         -6.696623 -0.224296  0.000000  0.259122
# Calcium_mean_slope                   -13.177524 -0.119916  0.000000  0.039787
# Alkaline Phosphatase_mean_slope      -14.649963  0.000000  0.095014  0.168129
# Albumin_pct_diff                      -7.681872 -0.297897  0.000000  0.112587
# Albumin_mean_slope                   -22.157163 -0.051092  0.000000  0.163118
# White Blood Cell (WBC)_pct_diff      -11.093303 -0.348259  0.000000  0.232296
# White Blood Cell (WBC)_mean_slope    -12.484816 -0.045948  0.000000  0.250922
# Hemoglobin_pct_diff                   -2.209259 -0.105085 -0.002644  0.000856
# Hemoglobin_mean_slope                 -4.852866 -0.080938  0.000000  0.095623
# Glucose_pct_diff                      -0.325202 -0.254068 -0.247063  0.000000
# Glucose_mean_slope                   -10.917070 -0.273570 -0.089554  0.000000
# ...                                         ...       ...       ...       ...
# mouth_pct_diff                       -12.614666  0.078391  0.078391  0.078391
# respiratory_pct_diff                  -9.338977 -0.008288 -0.008288 -0.008288
# respiratory_mean_slope                -9.274898  0.046324  0.046324  0.046324
# ALSFRS_Total_pct_diff                 -6.591089 -0.303154  0.054545  0.238909
# mouth_mean_slope                      -9.120927 -0.135526  0.075895  0.075895
# ALSFRS_Total_mean_slope               -5.755488 -0.345075  0.050589  0.282265
# hands_mean_slope                     -12.095604 -0.182350  0.145538  0.145538
# onset_delta_last                      -5.818394 -0.519422  0.264989  0.761543
# respiratory_mean                      -6.368440 -0.544227  0.620615  0.620615
# hands_mean                            -2.878253 -0.521343  0.098897  0.925883
# respiratory_last                      -6.870941 -1.314353  0.537843  0.537843
# mouth_mean                            -4.561869 -0.528542  0.439457  0.762123
# ALSFRS_Total_last                     -3.762360 -0.552391  0.160935  0.695930
# ALSFRS_Total_mean                     -3.591589 -0.583526  0.152490  0.728502
# mouth_last                            -4.563441 -0.581196  0.303748  0.746219
# hands_last                            -2.609781 -0.765762  0.156248  1.078258
# Bulbar                                -0.501303 -0.501303 -0.501303 -0.501303
# Black                                 -0.113384 -0.113384 -0.113384 -0.113384
# White                                 -4.516471  0.221311  0.221311  0.221311
# Unknown                               -0.137615 -0.137615 -0.137615 -0.137615
# Limb                                  -1.949922  0.512608  0.512608  0.512608
# Other                                 -0.060330 -0.060330 -0.060330 -0.060330
# Asian                                 -0.085475 -0.085475 -0.085475 -0.085475
# weight_mean                           -2.366146 -0.737715 -0.077483  0.609372
# weight_last                           -2.430883 -0.723363 -0.063206  0.615993
# Age_last                              -3.157604 -0.718925  0.064937  0.761702
# Limb and Bulbar                       -0.085475 -0.085475 -0.085475 -0.085475
# Hispanic                              -0.067481 -0.067481 -0.067481 -0.067481
# M                                     -1.338031 -1.338031  0.747028  0.747028
# F                                     -0.747028 -0.747028 -0.747028  1.338031
#
#                                             max
# family_ALS_hist_last                   1.947962
# temperature_mean_slope                16.070094
# temperature_pct_diff                  18.980697
# temperature_last                      21.007063
# temperature_mean                      16.785980
# BMI_last                               4.940542
# CK_mean_slope                         23.750234
# CK_pct_diff                           13.574082
# Gamma-glutamyltransferase_mean_slope  13.121901
# Gamma-glutamyltransferase_pct_diff    20.296371
# Total Cholesterol_pct_diff            38.824012
# Total Cholesterol_mean_slope           8.043222
# Platelets_pct_diff                     5.441130
# Platelets_mean_slope                   7.147809
# Protein_pct_diff                      30.943341
# Protein_mean_slope                    17.761069
# Phosphorus_mean_slope                  6.811118
# Phosphorus_pct_diff                   19.268325
# Calcium_pct_diff                      27.911746
# Alkaline Phosphatase_pct_diff          9.446154
# Calcium_mean_slope                    26.437502
# Alkaline Phosphatase_mean_slope        2.586341
# Albumin_pct_diff                      13.795377
# Albumin_mean_slope                     6.415043
# White Blood Cell (WBC)_pct_diff       13.369373
# White Blood Cell (WBC)_mean_slope      5.021316
# Hemoglobin_pct_diff                   26.397034
# Hemoglobin_mean_slope                 33.572081
# Glucose_pct_diff                       6.685378
# Glucose_mean_slope                     9.806788
# ...                                         ...
# mouth_pct_diff                        26.189822
# respiratory_pct_diff                  24.873548
# respiratory_mean_slope                20.990306
# ALSFRS_Total_pct_diff                 23.361300
# mouth_mean_slope                      15.841875
# ALSFRS_Total_mean_slope               23.440788
# hands_mean_slope                      12.386680
# onset_delta_last                       1.625115
# respiratory_mean                       0.620615
# hands_mean                             1.091280
# respiratory_last                       0.537843
# mouth_mean                             0.762123
# ALSFRS_Total_last                      1.765920
# ALSFRS_Total_mean                      1.784524
# mouth_last                             0.746219
# hands_last                             1.078258
# Bulbar                                 1.993896
# Black                                  8.815596
# White                                  0.221311
# Unknown                                7.263371
# Limb                                   0.512608
# Other                                 16.568055
# Asian                                 11.694035
# weight_mean                            4.605907
# weight_last                            4.519803
# Age_last                               2.242329
# Limb and Bulbar                       11.694035
# Hispanic                              14.812172
# M                                      0.747028
# F                                      1.338031
#
# [140 rows x 8 columns]

# %% [markdown]
# ## Pickle all metadata we will need to use later when applying vectorizer

# %%
pickle.dump( all_feature_metadata, open('../all_feature_metadata.pickle', 'wb') )
pickle.dump( train_data_means, open('../all_data_means.pickle', 'wb') )
pickle.dump( train_data_std, open('../all_data_std.pickle', 'wb') )

# %% [markdown]
# ## Apply model on `train`,  `test`

# %%
for t in ["all", "test"]:
    df = pd.read_csv('../' + t + '_data.csv', sep = '|', error_bad_lines=False, index_col=False, dtype='unicode')
    vectorized, _ = vectorize(df, all_feature_metadata)
    normalized, _ = normalize(vectorized, all_feature_metadata, train_data_means, train_data_std)
    print t, normalized.shape
    normalized.to_csv('../' + t + '_data_vectorized.csv' ,sep='|')

normalized.head()
# Out:
# all (2205, 140)
# test (600, 140)
#            family_ALS_hist_last    Bulbar      Limb  Limb and Bulbar  \
# SubjectID
# 750059                        0 -0.501303  0.512608        -0.085475
# 750094                        0 -0.501303  0.512608        -0.085475
# 750148                        0  1.993896 -1.949922        -0.085475
# 750195                        0  1.993896 -1.949922        -0.085475
# 750406                        0 -0.501303  0.512608        -0.085475
#
#            weight_last  weight_mean_slope  weight_mean  weight_pct_diff  \
# SubjectID
# 750059        2.136302           0.015749     2.061448         0.267218
# 750094       -0.577366           0.762399    -0.680211         1.355411
# 750148       -1.161351          -1.722087    -1.340747         0.107964
# 750195        1.333279          -0.552968     1.376093        -0.632499
# 750406        0.647732           0.705334     0.457092         2.105849
#
#            Sodium_last  Sodium_mean_slope         ...          \
# SubjectID                                         ...
# 750059       -1.797715           0.601348         ...
# 750094        0.081373           0.396271         ...
# 750148       -1.421897           0.133763         ...
# 750195        0.081373           0.139004         ...
# 750406        0.081373           0.258216         ...
#
#            Platelets_pct_diff  if_use_Riluzole_last  Protein_last  \
# SubjectID
# 750059              -0.459575             -1.403994     -0.776848
# 750094              -0.443557             -1.403994     -0.308146
# 750148              -0.013086              0.711884      0.394909
# 750195               2.080883             -1.403994      0.394909
# 750406              -0.171343              0.711884      1.097963
#
#            Protein_mean_slope  Protein_mean  Protein_pct_diff  ALT(SGPT)_last  \
# SubjectID
# 750059               0.589301     -0.901735          0.407644        0.225999
# 750094              -0.325235      0.057526         -0.594551       -0.307925
# 750148               0.175925     -0.024696          0.155231       -0.663874
# 750195              -0.999048     -0.390129          1.343320       -0.379115
# 750406              -1.115379      2.039998         -1.366227       -0.628279
#
#            ALT(SGPT)_mean_slope  ALT(SGPT)_mean  ALT(SGPT)_pct_diff
# SubjectID
# 750059                 0.179300       -0.183170            0.648286
# 750094                 0.148785       -0.380253           -0.073179
# 750148                -0.384791       -0.121892           -0.892634
# 750195                 2.170999        0.037100           -1.523329
# 750406                 0.003152       -0.820793           -0.123625
#
# [5 rows x 140 columns]
