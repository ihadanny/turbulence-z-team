# %%
import pandas as pd
import numpy as np
import pickle, cPickle
from datetime import datetime

from vectorizing_funcs import *
from modeling_funcs import *

# %%
tr_data = pd.read_csv('../all_data.csv', sep = '|', error_bad_lines=False, index_col=False, dtype='unicode')
tr_slope = pd.read_csv('../all_slope.csv', sep = '|', index_col="SubjectID")

test_data = pd.read_csv('../all_forms_validate_leader.txt', sep = '|', error_bad_lines=False, index_col=False, dtype='unicode')
test_slope = pd.read_csv('../ALSFRS_slope_validate_leader2.txt', sep = '|', index_col="SubjectID")

df = pd.concat([tr_data, test_data])
slope = pd.concat([tr_slope, test_slope])

slope.index = slope.index.astype(str)

print "*"*30
tick = datetime.now()

all_feature_metadata, train_data_means, train_data_std, train_data_medians, train_data_mads, \
             bins, forest, best_features_per_cluster, model_per_cluster = train_it(df, slope, 5)
clustering_model = {"model": forest, "bins": bins}

tock = datetime.now()   
diff = tock - tick 
print "minutes we learned: ", diff.seconds / 60

pickle.dump( all_feature_metadata, open('../all_feature_metadata.pickle', 'wb') )
pickle.dump( train_data_means, open('../all_data_means.pickle', 'wb') )
pickle.dump( train_data_std, open('../all_data_std.pickle', 'wb') )
pickle.dump( train_data_medians, open('../all_data_medians.pickle', 'wb') )
pickle.dump( train_data_mads, open('../all_data_mads.pickle', 'wb') )
pickle.dump( clustering_model, open('../forest_clustering_model.pickle', 'wb') )
pickle.dump( best_features_per_cluster, open("../best_features_per_cluster.pickle", "wb"))
pickle.dump( model_per_cluster, open("../model_per_cluster.pickle", "wb"))

print "pickled all models"
print "*"*30
# Out:
# ******************************
# train_data:  (2382, 130) (2382, 1)
# train cluster cnt:  [596 595 595 596]
# cluster: 0 with size: (596, 131) with mean target: -1.07408715139 std: 0.635979958005
# best we can do with all features: 0.603424577115
# using model: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None, min_samples_leaf=60,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=1000, n_jobs=1, oob_score=False, random_state=0,
#            verbose=0, warm_start=False)
# adding best family: ('fvc_percent', 0.62065126221266287) time: 18.3669998646
# adding best family: ('Blood Urea Nitrogen (BUN)', 0.6152367862158179) time: 25.6100001335
# adding best family: ('Creatinine', 0.61282429793836712) time: 33.4600000381
# adding best family: ('White Blood Cell (WBC)', 0.61040601421949492) time: 37.5380001068
# adding best family: ('onset_delta', 0.60911163404422175) time: 42.4140000343
# adding best family: ('ALSFRS_Total', 0.60795373396424968) time: 42.8710000515
# cluster: 1 with size: (595, 131) with mean target: -0.753920728335 std: 0.551043555272
# best we can do with all features: 0.507092385159
# using model: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None, min_samples_leaf=60,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=1000, n_jobs=1, oob_score=False, random_state=0,
#            verbose=0, warm_start=False)
# adding best family: ('onset_delta', 0.52531055129847581) time: 18.1940000057
# adding best family: ('AST(SGOT)', 0.51843707452863208) time: 22.4470000267
# adding best family: ('Blood Urea Nitrogen (BUN)', 0.51541224915355222) time: 30.5610001087
# adding best family: ('fvc_percent', 0.5133753577340231) time: 37.8210000992
# adding best family: ('Phosphorus', 0.51195726869422387) time: 42.2350001335
# adding best family: ('hands', 0.51070427074583258) time: 40.9719998837
# cluster: 2 with size: (595, 131) with mean target: -0.588352104963 std: 0.458222014269
# best we can do with all features: 0.434316118363
# using model: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None, min_samples_leaf=60,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=1000, n_jobs=1, oob_score=False, random_state=0,
#            verbose=0, warm_start=False)
# adding best family: ('Hemoglobin', 0.4484179995465073) time: 18.5210001469
# adding best family: ('bp_diastolic', 0.44443571941924181) time: 25.3639998436
# adding best family: ('Calcium', 0.4414649479171931) time: 30.0720000267
# adding best family: ('onset_delta', 0.43917861865335972) time: 34.6229999065
# adding best family: ('Bilirubin (Total)', 0.43808816156668401) time: 36.993999958
# adding best family: ('Glucose', 0.43737924255304145) time: 41.9070000648
# cluster: 3 with size: (596, 131) with mean target: -0.340724797605 std: 0.379250377762
# best we can do with all features: 0.356974577992
# using model: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None, min_samples_leaf=60,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=1000, n_jobs=1, oob_score=False, random_state=0,
#            verbose=0, warm_start=False)
# adding best family: ('fvc_percent', 0.37011044867107135) time: 18.4399998188
# adding best family: ('Phosphorus', 0.36674451666220914) time: 29.1239998341
# adding best family: ('respiratory_rate', 0.36446904500721089) time: 33.0490000248
# adding best family: ('pulse', 0.36259486320034223) time: 36.1080000401
# adding best family: ('bp_systolic', 0.36160913883632839) time: 40.5710000992
# adding best family: ('Creatinine', 0.36071498072247393) time: 45.3559999466
# best_features_per_cluster:  {0: ['ALSFRS_Total', 'White Blood Cell (WBC)', 'fvc_percent', 'onset_delta', 'Creatinine', 'Blood Urea Nitrogen (BUN)'], 1: ['AST(SGOT)', 'fvc_percent', 'hands', 'onset_delta', 'Blood Urea Nitrogen (BUN)', 'Phosphorus'], 2: ['Hemoglobin', 'bp_diastolic', 'Calcium', 'onset_delta', 'Bilirubin (Total)', 'Glucose'], 3: ['bp_systolic', 'respiratory_rate', 'pulse', 'Creatinine', 'fvc_percent', 'Phosphorus']}
# cluster: 2 size: (595L,)
# 	 RMS error (0 is perfect): 0.45
# 	 coefficient of determination R^2 = 0.05
# 	 pearson correlation r = 0.22
# 3 sample predictions:  [-0.636248   -0.52704315 -0.5595475 ]
# cluster: 1 size: (595L,)
# 	 RMS error (0 is perfect): 0.54
# 	 coefficient of determination R^2 = 0.05
# 	 pearson correlation r = 0.24
# 3 sample predictions:  [-0.71000832 -0.64302014 -0.74551193]
# cluster: 3 size: (596L,)
# 	 RMS error (0 is perfect): 0.38
# 	 coefficient of determination R^2 = 0.01
# 	 pearson correlation r = 0.13
# 3 sample predictions:  [-0.3396437  -0.32571029 -0.34588149]
# cluster: 0 size: (596L,)
# 	 RMS error (0 is perfect): 0.62
# 	 coefficient of determination R^2 = 0.03
# 	 pearson correlation r = 0.19
# 3 sample predictions:  [-1.05758614 -0.97955732 -1.09063746]
# minutes we learned:  17
# pickled all models
# ******************************
